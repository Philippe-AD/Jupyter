# %% [markdown]
# <a href="https://colab.research.google.com/github/Philippe-AD/Jupyter/blob/master/PhrasesEnFr.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%writefile phrases.txt
# Il y a longtemps que je n'ai pas essayé.
# It's been a long time since I've tried.
# Cliquez sur le bouton ci-dessous et parlez de quelque chose...
# Click on the below button and speak something..
# Traductions rapides, précises et sûres
# Fast, accurate and reliable translations
# Out:
# Overwriting phrases.txt

# %%
# %%writefile phrases.txt
# Français
# French
# Englais
# English
# Tiens, range ceci dans le tiroir !
# Here, put this away in the drawer!
# Ceci marche avec des piles, mais pas cela.
# This works with batteries, but not that.
# L'environnement est une cause importante. Je comprends cela.
# The environment is an important cause. I understand that.
# N'oubliez jamais ceci : l'adjectif s'accorde toujours avec le nom.
# Never forget this: the adjective always agrees with the noun.
# Cela dit, il est quand même un très bon ami.
# That said, he's still a very good friend.
# J'ai toujours détesté ça !
# I've always hated that!
# N'oubliez jamais ça : l'adjectif s'accorde toujours avec le nom.
# Never forget this: the adjective always agrees with the noun.
# Ceci m'appartient, cela t'appartient.
# This belongs to me, that belongs to you.
# Ceci, dans ma main, est un stylo, et cela, sur la table, est un crayon à papier.
# This, in my hand, is a pen, and that, on the table, is a pencil.
# Faire mes devoirs ou dormir, je préfère ceci plutôt que cela.
# Doing my homework or sleeping, I prefer the latter rather than the former.
# Tu as pratiqué Philippe ?
# Have you been practising Philippe?
# Découvrez combien vous vous êtes amélioré.
# Find out how much you have improved.
# Testez maintenant !
# Test now!
# Apprenez-en davantage sur ces sujets connexes de grammaire française
# Learn more about these related French grammar topics
# Exemples et ressources
# Examples and resources
# Ceci marche avec des piles, mais pas cela.
# This works with batteries, but not that.
# Tiens, range ça dans le tiroir !
# Here, put this away in the drawer!
# Ceci m'appartient, cela t'appartient.
# This belongs to me, that belongs to you.
# Tiens, range ceci dans le tiroir !
# Here, put this away in the drawer!
# N'oubliez jamais ça : l'adjectif s'accorde toujours avec le nom.
# Never forget this: the adjective always agrees with the noun.
# N'oubliez jamais ceci : l'adjectif s'accorde toujours avec le nom.
# Never forget this: the adjective always agrees with the noun.
# Faire mes devoirs ou dormir, je préfère ceci plutôt que cela.
# Doing my homework or sleeping, I prefer the latter rather than the former.
# J'ai toujours détesté ça !
# I've always hated that!
# Cela dit, il est quand même un très bon ami.
# That said, he's still a very good friend.
# Ceci, dans ma main, est un stylo, et cela, sur la table, est un crayon à papier.
# This, in my hand, is a pen, and that, on the table, is a pencil.
# J'ai toujours détesté cela !
# I've always hated that!
# L'environnement est une cause importante. Je comprends cela.
# The environment is an important cause. I understand that.
# Notre entreprise s'est développée rapidement cette année.
# Our company has grown rapidly this year.
# Il a fait tomber son crayon.
# He dropped his pencil.
# Mon crayon est tombé.
# My pencil fell.
# Le verre est tombé et c'est cassé.
# The glass fell and broke.
# J'ai glissé et je suis tombé, mais je ne me suis pas blessé.
# I slipped and fell, but I didn't hurt myself.
# J'arrive à la gare.
# I'm arriving at the station.
# Qu'est-ce qui t'arrive ?
# What's happening to you?
# Je suis venu te voir.
# I came to see you.
# Tu es rentré tard.
# You came home late.
# Le voleur est entré par la fenêtre.
# The thief entered by the window.
# Nous sommes revenus.
# We came back.
# Vous êtes allés au cirque hier.
# You went to the circus yesterday.
# Marc est tombé par terre.
# Marc fell on the floor.
# Ils sont arrivés à l'heure.
# They arrived on time.
# Le garçon mange une pomme.
# The boy is eating an apple.
# La fille est jolie.
# The girl is pretty.
# L'animal est timide.
# The animal is shy.
# Elle est dans l'hôtel.
# She is in the hotel.
# Bas les masques !
# Take off the masks!
# Le vampire est caché.
# The vampire is hidden.
# L'étoile est dans le ciel.
# The star is in the sky.
# La voiture est rouge.
# The car is red.
# Je vois le restaurant.
# I see the restaurant.
# Où sont les voitures ?
# Where are the cars?
# Il aime l'ail.
# He likes garlic.
# C'est la vie !
# That's life!
# J'aime la bière.
# I love beer.
# Parlons de la politique.
# Let's talk about politics.
# Il est plombier.
# He's a plumber.
# Elle est étudiante.
# She's a student.
# Le weekend prochain, nous allons à Brighton.
# Next weekend, we're going to Brighton.
# La semaine dernière, j'ai rencontré ses parents.
# Last week, I met her parents.
# La fois dernière, c'était parce qu'il était malade!
# Last time, it was because he was sick!
# Le mois dernier, j'ai passé deux semaines à l'étranger.
# Last month, I spent two weeks abroad.
# L'année prochaine, il commence l'université.
# Next year, he's starting university.
# Mardi prochain, elle va à un concert.
# Next Tuesday, she is going to a concert.
# En septembre prochain, Gareth visitera Madrid.
# Next September, Gareth will visit Madrid.
# En janvier dernier, Simon a emménagé en France.
# Last January, Simon moved to France.
# Dimanche je vais à la gym. Tu veux dire dimanche prochain?
# On Sunday I'm going to the gym. You mean next Sunday?
# Je vais à l'université l'année prochaine.
# I go to university next year.
# Out:
# Writing phrases.txt

# %%
import pprint
import numpy as np
import pandas as pd

text_file = open("phrases.txt", "r")
lines = text_file.readlines()
text_file.close()

# using naive method
# Separating odd and even index elements
my_array = []
l = []
for i in range(0, len(lines)):
    if i % 2:
        l.append(lines[i])
        l.append(len(lines[i]))
        my_array.append(l)
        l=[]
    else :
        l.append(lines[i])
 
print("***********************************************")     

df = pd.DataFrame(my_array, columns = ['FR','EN','LEN'])
print(df)
df.to_csv("phrases.csv")
# Out:
# ***********************************************
#                                                    FR  ... LEN
# 0                                          Français\n  ...   7
# 1                                           Englais\n  ...   8
# 2                Tiens, range ceci dans le tiroir !\n  ...  35
# 3        Ceci marche avec des piles, mais pas cela.\n  ...  41
# 4   L'environnement est une cause importante. Je c...  ...  58
# ..                                                ...  ...  ..
# 64            Mardi prochain, elle va à un concert.\n  ...  41
# 65   En septembre prochain, Gareth visitera Madrid.\n  ...  42
# 66  En janvier dernier, Simon a emménagé en France.\n  ...  37
# 67  Dimanche je vais à la gym. Tu veux dire dimanc...  ...  54
# 68        Je vais à l'université l'année prochaine.\n  ...  29
#
# [69 rows x 3 columns]

# %%
df = df.sort_values(by=['LEN'], ascending=True)
df
# Out:
#                                                    FR  ... LEN
# 0                                          Français\n  ...   7
# 1                                           Englais\n  ...   8
# 14                              Testez maintenant !\n  ...  10
# 55                                 J'aime la bière.\n  ...  13
# 54                                   C'est la vie !\n  ...  13
# ..                                                ...  ...  ..
# 22  N'oubliez jamais ceci : l'adjectif s'accorde t...  ...  62
# 10  Ceci, dans ma main, est un stylo, et cela, sur...  ...  65
# 26  Ceci, dans ma main, est un stylo, et cela, sur...  ...  65
# 23  Faire mes devoirs ou dormir, je préfère ceci p...  ...  75
# 11  Faire mes devoirs ou dormir, je préfère ceci p...  ...  75
#
# [69 rows x 3 columns]

# %%
# making data frame from csv file
data = pd.read_csv("phrases.csv", index_col ="FR")
  
# retrieving columns by indexing operator
first = data["EN"] 
print(first)
# Get the unique values of 'E' column
df = first.unique()
df
# Out:
# FR
# Français\n                                                                                                 French\n
# Englais\n                                                                                                 English\n
# Tiens, range ceci dans le tiroir !\n                                           Here, put this away in the drawer!\n
# Ceci marche avec des piles, mais pas cela.\n                             This works with batteries, but not that.\n
# L'environnement est une cause importante. Je comprends cela.\n    The environment is an important cause. I under...
#                                                                                         ...
# Mardi prochain, elle va à un concert.\n                                  Next Tuesday, she is going to a concert.\n
# En septembre prochain, Gareth visitera Madrid.\n                        Next September, Gareth will visit Madrid.\n
# ...

# %%
df = pd.DataFrame(data, columns = ['EN_Unique'])
print(df)
df.to_csv("phrases-en_unique.csv")
# Out:
#                                                     EN_Unique
# FR
# Français\n                                                NaN
# Englais\n                                                 NaN
# Tiens, range ceci dans le tiroir !\n                      NaN
# Ceci marche avec des piles, mais pas cela.\n              NaN
# L'environnement est une cause importante. Je co...        NaN
# ...                                                       ...
# Mardi prochain, elle va à un concert.\n                   NaN
# En septembre prochain, Gareth visitera Madrid.\n          NaN
# En janvier dernier, Simon a emménagé en France.\n         NaN
# Dimanche je vais à la gym. Tu veux dire dimanch...        NaN
# Je vais à l'université l'année prochaine.\n               NaN
#
# [69 rows x 1 columns]

# %%
# %%writefile phrases_2.txt
# attendez-nous là
# wait for us there
# avez-vous faim?
# are you hungry (formal)?
# c'est pour vous
# it is for you (formal)
# c'est quoi?
# what is it?
# c'est tout?
# is that all?
# c'est très gentil
# it is very nice
# c’est combien?
# how much is it?
# c’est grave?
# is it serious?
# ça n'est pas grave
# no problem
# ce n’est pas comme ça
# It is not like that
# combien cela coûte?
# how much is this?
# comment as-tu passé... ?
# how have you spent...? (informal)
# comment t'appelles-tu?
# what's your name (informal)?
# comment vas-tu?
# how are you (informal)?
# depuis quand?
# since when?
# il est prêt
# he is ready
# il veut y aller
# he wants to go there
# j'ai déjà dit que
# I have already said that
# j’attends mes amis
# I am waiting for my friends
# je ne comprends
# pas	I don't understand
# je ne sais pas
# I don't know
# je serai à
# I will be at
# je suis arrivé
# I have arrived (m)
# je suis désolé
# I am sorry (m)
# je suis perdu
# I'm lost (m)
# je suis près de
# I am close to
# je te tiens au courant
# I'll let you know (informal)
# je vais être en retard
# I'll be late
# ne t'inquiète pas!
# don't worry (informal)!
# nous parlerons plus tard
# we will speak later
# où on se retrouve?
# where do we meet?
# où pouvons-nous manger?
# where can we eat?
# où sont les toilettes?
# where is the bathroom?
# où veux-tu dîner?
# where do you want to have dinner? (informal)
# parlez-vous anglais?
# do you speak English? (formal)
# pas du tout
# not at all
# pas pour moi
# not for me
# peux-tu m'aider?
# can you help me (informal)?
# pourquoi pas?
# why not?
# pourriez-vous répéter?
# can you say it again? (formal)
# puis-je faire ça?
# can I do that?
# qu'est-ce qui se passe?
# what is happening?
# qu’est-ce que vous recommandez?
# what do you recommend (formal)?
# que voulez-vous faire?
# what do you want to do (formal)?
# qui est-ce?	who is it?
# quoi de neuf?
# what's new?
# tu vas y aller
# you are going to go there (informal)
# va-t'en!
# go away!
# viens avec moi!
# come with me! (informal)
# Out:
# Writing phrases_2.txt

# %%
import pprint
import numpy as np
import pandas as pd

text_file = open("phrases_2.txt", "r")
lines = text_file.readlines()
text_file.close()

# using naive method
# Separating odd and even index elements
my_array = []
l = []
for i in range(0, len(lines)):
    if i % 2:
        l.append(lines[i])  # englais !
        l.append(len(lines[i]))  
        if lines[i].find("(formal)") > 0:
          l.append("formal")
        else:
          pass  # l.append('-')  
        
        my_array.append(l)
        l=[]
    else :
        l.append(lines[i])
 
print("***********************************************")     

df = pd.DataFrame(my_array, columns = ['FR','EN','LEN','FORMAL'])
print(df)
df.to_csv("phrases_2.csv")
# Out:
# ***********************************************
#                                         FR  ...  FORMAL
# 0                     attendez-nous là\t\n  ...    None
# 1                      avez-vous faim?\t\n  ...  formal
# 2                      c'est pour vous\t\n  ...  formal
# 3                          c'est quoi?\t\n  ...    None
# 4                          c'est tout?\t\n  ...    None
# 5                    c'est très gentil\t\n  ...    None
# 6                       c’est combien?\t\n  ...    None
# 7                         c’est grave?\t\n  ...    None
# 8                   ça n'est pas grave\t\n  ...    None
# 9                ce n’est pas comme ça\t\n  ...    None
# 10                 combien cela coûte?\t\n  ...    None
# 11            comment as-tu passé... ?\t\n  ...    None
# 12              comment t'appelles-tu?\t\n  ...    None
# 13                     comment vas-tu?\t\n  ...    None
# 14                       depuis quand?\t\n  ...    None
# ...

# %% [markdown]
# ---

# %%
# %%writefile phrases.csv
# 130 phrases utiles a connaitre en anglais
# A
# A while back / A while ago --> Il y a quelques temps
# After a while --> Au bout d'un moment, Au bout d'un certain temps
# Ahead of time --> En avance, Au prealable
# All along --> Le long de, Tout le long
# All day long --> Toute la journee
# All in all --> Somme toute, Apres tout, En fin de compte
# All the while --> Pendant tout ce temps-l・ Depuis le debut
# Any day (now) --> D'un jour ・l'autre
# Around the clock --> Jour et nuit
# As a rule --> Generalement, D'habitude
# As if / As though --> Comme si, Avec l'air de
# As much as --> Autant que
# As usual --> Comme d'habitude
# As well as --> Comme, Ainsi que, Et aussi
# At a moment's notice --> Sur le champ, Immediatement
# At a time --> a la fois (three at a time), En meme temps (for months at a time)
# At any price --> a tout prix
# At all times --> a tout moment
# At last / At long last --> Enfin
# At one time / At one point --> a un moment donn・
# At this rate --> a ce rythme
# At the moment --> Actuellement, En ce moment
# At the same time --> En meme temps
# At the worst possible time --> Au pire moment
# B
# To be in for it --> Avoir des ennuis
# Be that as it may --> Quoi qu段l en soit, Ceci 騁ant
# To be quits (with somebody) --> ﾊtre quitte (envers quelqu'n)
# To be well-off --> ﾊtre ais・ ﾊtre riche
# By all means --> Certainement, Absolument
# By any means --> Par tous les moyens
# By no means --> En aucun cas
# By way of --> En passant par
# C
# Carry on --> Continuer
# D
# Day after day / Day by day / Day in / day out --> Jour apres jour
# From day to day --> D'n jour ・l誕utre
# To be down and out --> ﾊtre ・la rue
# E
# To eat one's words --> Ravaler ses paroles, Se r騁racter
# Either way --> De toute mani鑽e, Dans tous les cas
# Every now and then / Once in a while --> De temps en temps, Parfois
# F
# For a change --> Pour changer
# For good --> Pour toujours
# For the moment / For the present --> Pour l段nstant, Pour le moment
# From now on --> a partir de maintenant, Dor駭anavant
# From scratch / From the ground up --> a partir de z駻o
# From this day forward --> a partir d誕ujourd檀ui
# From time to time --> De temps en temps
# From way back --> Depuis tres longtemps
# H
# Hard times --> Temps durs, Temps difficiles
# To have a hard time / To have a tough time --> Avoir du mal ・faire quelque chose
# To have a way with something --> S馳 connitre en quelque chose, Savoir s馳 prendre
# To have all the time in the world --> Avoir tout son temps
# It's high time that・--> Il est grand temps que・
# His days are numbered --> Ses jours sont comptes
# However much・/ No matter how・--> Avoir beau・
# Hurry up! --> Depeche-toi !
# I
# I mean it --> Je ne plaisante pas
# I値l never get over it --> Je ne m弾n remettrais jamais, Je n弾n reviens pas
#  I wish I knew --> J誕imerais bien le savoir
#  It doesn稚 matter --> Peu importe
#  It doesn稚 make sense --> ﾇa n誕 aucun sens
#  It's about time! --> Ce n弾st pas trop t !
#  It's all the same to me --> ﾇa m弾st compl鑼ement 馮al
#  It's beside the point --> L・n弾st pas la question
#  It's news to me --> ﾇa, c弾st du nouveau
#  It's up to you --> C弾st ・toi de d馗ider
#  It's a waste of time --> C弾st une perte de temps
#  In every sense of the word --> Dans tous les sens du terme
#  In his day --> a son 駱oque
#  In no time at all --> En moins de deux, Bient
#  In the good old days --> Au bon vieux temps
#  In place --> En place
#  In the meantime --> Pendant ce temps, En attendant, Entre-temps, Au meme moment
#  In time / Just in time --> a temps, Juste ・temps
#  In vain --> En vain
#  It can wait --> ﾇa peut attendre
#  It could be worse --> ﾇa aurait pu 黎re pire
#  It was quite a job! --> C帝tait toute une affaire !, Quel boulot !
#  It's a no-go --> ﾇa ne marche pas, ﾇa ne sert ・rien
#  It's a matter of time --> C弾st une question de temps
#  J
#  Just about --> Presque, a peu pres
#  Just now --> a l段nstant
#  K
#  o know one's place --> Savoir rester ・sa place
# To know somebody by sight --> Connitre quelqu'n de vue
# L
# Let's clear it up --> Resoudre un probl鑪e, Tirer quelque chose au clair
# Let's drop the subject --> Parlons d誕utre chose
# M
# To make a show of something --> En faire tout un spectacle, Faire 騁alage de quelque chose
# To make haste --> Se d駱鹹her
# To make time --> Trouver le temps de faire quelque chose
# Mind your own business --> Occupe-toi de tes affaires, ﾇa ne te regarde pas
# More often than not --> Le plus souvent
# N
# No matter --> Peu importe
# O
# On and off --> De temps en temps
# On and on -->Pendant des heures, a n弾n pas finir
# On the spot --> Imm馘iatement, Sur-le-champ
# On time --> a l檀eure
# Once and for all --> Une bonne fois pour toutes
# Once in a while --> De temps en temps
# Out of date --> D駑od・
# P
# To play for time --> Essayer de gagner du temps
# Point of view --> Point de vue
# Pros and cons --> Le pour et le contre
# R
# Right now --> Tout de suite
# To run for one's life --> S弾nfuir pour sauver sa peau
# To run out of time --> Ne plus avoir de temps
# S
# To say one's piece --> Dire ce que l弛n a ・dire
# To set the pace --> Imposer le rythme, Marquer le ton
# To side against --> Prendre parti contre quelqu'n
# So far / As of yet --> Jusqu段ci, Pour l段nstant
# Sooner or later --> T ou tard
# To speak too soon --> Parler trop t
# To speak one's mind --> Dire ce que l弛n pense
# To stand one's ground --> Tenir bon
# To stand to reason --> Aller sans dire, ﾊtre logique
# T
# To take sides --> Prendre parti
# To take a stand --> Prendre position sur quelque chose
# To take time --> Prendre du temps
# Take your time! --> Prends ton temps !
# Time after time / Time and time again --> Maintes fois, a maintes reprises
# Time is up --> C弾st l檀eure, C弾st fini
# Time out --> Pause, Temps mort
# Time will tell --> L誕venir le dira
# Time is getting short --> Le temps presse
# That's not the point --> La question n弾st pas l・
# The whole year round, All the year round --> Toute l誕nnee
# There is no hurry --> ﾇa ne presse pas, Il n馳 a pas le feu
# Throw good money after bad --> Investir en pure perte, Gaspiller de l誕rgent
# To one's face --> En pleine figure
# U
# Until the end of time --> Jusqu'・la fin des temps
# (To be) up against --> ﾊtre confront・
# To use your own judgement --> Faire comme bon vous semble, a vous de d馗ider
# W
# What are you driving at? --> O・veux-tu en venir ?, Que veux-tu dire ?
# What for? --> Pourquoi ?, a quel sujet ?
# What of it? --> Et alors ?
# Wait and see --> Attendre de voir comment/pourquoi
# Y
# You can take it from me --> Crois-moi
# Out:
# Writing phrases.csv

# %%
# %%writefile phrases.csv
# attendez-nous là	wait for us there
# avez-vous faim?	are you hungry (formal)?
# c'est pour vous	it is for you (formal)
# c'est quoi?	what is it?
# c'est tout?	is that all?
# c'est très gentil	it is very nice
# c’est combien?	how much is it?
# c’est grave?	is it serious?
# ça n'est pas grave	no problem
# ce n’est pas comme ça	It is not like that
# combien cela coûte?	how much is this?
# comment as-tu passé... ?	how have you spent...? (informal)
# comment t'appelles-tu?	what's your name (informal)?
# comment vas-tu?	how are you (informal)?
# depuis quand?	since when?
# il est prêt	he is ready
# il veut y aller	he wants to go there
# j'ai déjà dit que	I have already said that
# j’attends mes amis	I am waiting for my friends
# je ne comprends pas	I don't understand
# je ne sais pas	I don't know
# je serai à	I will be at
# je suis arrivé	I have arrived (m)
# je suis désolé	I am sorry (m)
# je suis perdu	I'm lost (m)
# je suis près de	I am close to
# je te tiens au courant	I'll let you know (informal)
# je vais être en retard	I'll be late
# ne t'inquiète pas!	don't worry (informal)!
# nous parlerons plus tard	we will speak later
# où on se retrouve?	where do we meet?
# où pouvons-nous manger?	where can we eat?
# où sont les toilettes?	where is the bathroom?
# où veux-tu dîner?	where do you want to have dinner? (informal)
# parlez-vous anglais?	do you speak English? (formal)
# pas du tout	not at all
# pas pour moi	not for me
# peux-tu m'aider?	can you help me (informal)?
# pourquoi pas?	why not?
# pourriez-vous répéter?	can you say it again? (formal)
# puis-je faire ça?	can I do that?
# qu'est-ce qui se passe?	what is happening?
# qu’est-ce que vous recommandez?	what do you recommend (formal)?
# que voulez-vous faire?	what do you want to do (formal)?
# qui est-ce?	who is it?
# quoi de neuf?	what's new?
# tu vas y aller	you are going to go there (informal)
# va-t'en!	go away!
# viens avec moi!	come with me! (informal)

# %%
text = "By 1908, Einstein was recognized as a leading scientist and was appointed lecturer at the University of Bern"
text = "We want to get an overview of the length of the words in this text. We can create a dictionary that contains both the words and their lengths. Dictionary comprehension accomplishes this task simply as follows:"
dict_a = {x: len(x) for x in text.split(" ")}
dict_a
# Out:
# {'Dictionary': 10,
#  'We': 2,
#  'a': 1,
#  'accomplishes': 12,
#  'an': 2,
#  'and': 3,
#  'as': 2,
#  'both': 4,
#  'can': 3,
#  'comprehension': 13,
#  'contains': 8,
#  'create': 6,
#  'dictionary': 10,
#  'follows:': 8,
#  'get': 3,
#  'in': 2,
#  'length': 6,
#  'lengths.': 8,
#  'of': 2,
#  'overview': 8,
#  'simply': 6,
#  'task': 4,
#  'text.': 5,
#  'that': 4,
#  'the': 3,
#  'their': 5,
#  'this': 4,
#  'to': 2,
#  'want': 4,
#  'words': 5}

# %%
# !pip install textacy

# %%
import textacy

# %%
 text = (
     "Since the so-called \"statistical revolution\" in the late 1980s and mid 1990s, "
     "much Natural Language Processing research has relied heavily on machine learning. "
     "Formerly, many language-processing tasks typically involved the direct hand coding "
     "of rules, which is not in general robust to natural language variation. "
     "The machine-learning paradigm calls instead for using statistical inference "
     "to automatically learn such rules through the analysis of large corpora "
     "of typical real-world examples."
)

# %%
from textacy import extract
list(extract.keyword_in_context(text, "language", window_width=25, pad_context=True))
# Out:
# [(' mid 1990s, much Natural ', 'Language', ' Processing research has '),
#  ('learning. Formerly, many ', 'language', '-processing tasks typical'),
#  ('eneral robust to natural ', 'language', ' variation. The machine-l')]

# %%
from textacy import preprocessing
preprocessing.normalize.whitespace(preprocessing.remove.punctuation(text))[:800]
# Out:
# 'Since the so called statistical revolution in the late 1980s and mid 1990s much Natural Language Processing research has relied heavily on machine learning Formerly many language processing tasks typically involved the direct hand coding of rules which is not in general robust to natural language variation The machine learning paradigm calls instead for using statistical inference to automatically learn such rules through the analysis of large corpora of typical real world examples'

# %%
texts = [
     "Mary had a little lamb. Its fleece was white as snow.",
     "Everywhere that Mary went the lamb was sure to go.",
]
'''docs = [make_spacy_doc(text, lang="en_core_web_sm") for text in texts]
data = [tok.text for tok in docs[0]]
graph = build_cooccurrence_network(data, window_size=2)
sorted(graph.adjacency())[0]'''
# Out:
# 'docs = [make_spacy_doc(text, lang="en_core_web_sm") for text in texts]\ndata = [tok.text for tok in docs[0]]\ngraph = build_cooccurrence_network(data, window_size=2)\nsorted(graph.adjacency())[0]'

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import pprint

myvar = [
    {"acr", "UK", "Royaume-Uni", "", "742", "", ""},
    {"adj adv prep", " next", " après; ensuite; prochain", " tp_struct", "132", "", ""},
    {"adj adv pron", " such", " tel; tellement; ceux", " tp_struct", "175", "", ""},
    {"adj adv", " both", " les deux; tous les deux", "", "215", "", ""},
    {"adj adv", " far", " loin; beaucoup", "", "258", "", ""},
    {"adj adv", " last", " dernier; dernière", "", "105", "", ""},
    {"adj adv", " late", " tardif; tardive; en retard; trop tard", "", "269", "", ""},
    {"adj adv", " now", " maintenant; en ce moment", "", "55", "", ""},
    {"adj adv", " true", " vrai; fidèle", "", "453", "", ""},
    {"adj adv", "less", "moins", "", "818", "", ""},
    {"adj conj", " such as", " comme; tel que", " tp_struct", "217", "", ""},
    {"adj det", " few", " peu", "", "161", "", ""},
    {"adj det", " own", " propre; personnel", "", "188", "", ""},
    {"adj det", " several", " plusieurs", "", "491", "", ""},
    {"adj det", "half", "demi", "", "784", "", ""},
    {"adj num", " second", " deuxième; second; seconde", " tp_quantity tp_struct", "204", "", ""},
    {"adj prep", " outside", " extérieur; du dehors; dehors", "", "481", "", ""},
    {"adj pron", " all", " tout; toute; tous", " tp_struct tp_quantity", "24", "", ""},
    {"adj pron", " any", " n'importe quel; quelque; [negative, question]", " tp_struct", "89", "", ""},
    {"adj pron", " each", " chaque; chacun; chacune; tout; toute", " tp_struct", "153", "", ""},
    {"adj pron", " some", " quelconque; quelque; quelques-uns", " tp_struct", "40", "", ""},
    {"adj", " able", " capable; compétent", "", "442", "", ""},
    {"adj", " adv", " just", " juste; exact; valable; seulement", "", "67", ""},
    {"adj", " American", " américain", "", "482", "", ""},
    {"adj", " another", " un autre; une autre; encore un", "", "126", "", ""},
    {"adj", " bad", " mauvais; mal", "", "298", "", ""},
    {"adj", " big", " grand; gros; grande [f]; grosse [f]", "", "147", "", ""},
    {"adj", " black", " noir", "", "237", "", ""},
    {"adj", " British", " britannique; anglais", "", "193", "", ""},
    {"adj", " clear", " clair; pure; transparent", "", "498", "", ""},
    {"adj", " close", " proche; limité", "", "294", "", ""},
    {"adj", " cold", " froid; impitoyable", "", "425", "", ""},
    {"adj", " different", " différent; autre", "", "187", "", ""},
    {"adj", " early", " premier; précoce; de bonne heure; tôt", "", "233", "", ""},
    {"adj", " European", " européen; européenne", "", "441", "", ""},
    {"adj", " every", " chaque", "", "131", "", ""},
    {"adj", " fine", " excellent; bien; délicat", "", "297", "", ""},
    {"adj", " full", " plein; complet; entier", "", "300", "", ""},
    {"adj", " good", " bon; bonne; gentil", "", "56", "", ""},
    {"adj", " great", " grand; excellent; magnifique; génial", "", "127", "", ""},
    {"adj", " green", " vert; écologique", "", "485", "", ""},
    {"adj", " happy", " heureux; joyeux", "", "411", "", ""},
    {"adj", " hard", " dur; ferme; rude", "", "295", "", ""},
    {"adj", " high", " haut; élevé; grand", "", "160", "", ""},
    {"adj", " important", " important", "", "378", "", ""},
    {"adj", " large", " étendu; grand; large", "", "158", "", ""},
    {"adj", " left", " gauche; de gauche", "", "487", "", ""},
    {"adj", " little", " petit; petite; peu de; un peu", "", "135", "", ""},
    {"adj", " long", " long; longue; grand", "", "137", "", ""},
    {"adj", " low", " bas; basse", "", "360", "", ""},
    {"adj", " many", " beaucoup; nombreux", "", "80", "", ""},
    {"adj", " new", " neuf; nouveau; nouvelle", "", "90", "", ""},
    {"adj", " nice", " agréable; aimable; charmant", "", "349", "", ""},
    {"adj", " old", " vieux; âgé; ancien", "", "95", "", ""},
    {"adj", " only", " seul; unique; seulement", "", "229", "", ""},
    {"adj", " open", " ouvert; ouverte; libre; franc", "", "283", "", ""},
    {"adj", " poor", " pauvre; médiocre", "", "377", "", ""},
    {"adj", " possible", " possible; acceptable", "", "374", "", ""},
    {"adj", " present", " présent; être présent", "", "384", "", ""},
    {"adj", " ready", " prêt; disposé", "", "466", "", ""},
    {"adj", " real", " vrai; réel; véritable", "", "318", "", ""},
    {"adj", " red", " rouge; roux", "", "390", "", ""},
    {"adj", " right", " droite; juste; exact; bien", "", "167", "", ""},
    {"adj", " same", " même", "", "166", "", ""},
    {"adj", " short", " court; petit; bref", "", "412", "", ""},
    {"adj", " small", " petit", "", "162", "", ""},
    {"adj", " strong", " fort; puissant", "", "426", "", ""},
    {"adj", " sure", " sûr; assuré; certain", "", "197", "", ""},
    {"adj", " top", " en haut; premier; meilleur", "", "440", "", ""},
    {"adj", " white", " blanc", "", "246", "", ""},
    {"adj", " whole", " entier; complet", "", "362", "", ""},
    {"adj", " wide", " large", "", "462", "", ""},
    {"adj", " young", " jeune", "", "270", "", ""},
    {"adj", "afraid", "désolé; effrayé", "", "820", "", ""},
    {"adj", "basic", "fondamental; principal; élémentaire", "", "714", "", ""},
    {"adj", "be worth", "valoir", "", "861", "", ""},
    {"adj", "beautiful", "beau; bel", "", "558", "", ""},
    {"adj", "blue", "bleu", "", "546", "", ""},
    {"adj", "born", "né", "", "757", "", ""},
    {"adj", "bright", "brillant; clair; vif", "", "825", "", ""},
    {"adj", "brown", "brun; marron", "", "970", "", ""},
    {"adj", "busy", "occupé; actif; énergique", "", "958", "", ""},
    {"adj", "central", "central; principal", "", "894", "", ""},
    {"adj", "certain", "certain; sûr", "", "597", "", ""},
    {"adj", "clean", "propre; pur", "", "866", "", ""},
    {"adj", "common", "courant; commun; ordinaire", "", "914", "", ""},
    {"adj", "dark", "sombre; foncé; obscur", "", "522", "", ""},
    {"adj", "dead", "mort; décédé", "", "564", "", ""},
    {"adj", "deep", "profond", "", "665", "", ""},
    {"adj", "dry", "sec; séché", "", "884", "", ""},
    {"adj", "easy", "facile; naturel; simple", "", "516", "", ""},
    {"adj", "English", "anglais; anglaise", "", "520", "", ""},
    {"adj", "fair", "équitable; juste", "", "629", "", ""},
    {"adj", "fast", "rapide; solide; bien attaché", "", "915", "", ""},
    {"adj", "foreign", "étranger; extérieur", "", "509", "", ""},
    {"adj", "free", "libre; gratuit", "", "583", "", ""},
    {"adj", "fresh", "frais; fraîche", "", "869", "", ""},
    {"adj", "front", "de devant; premier; ventral", "", "621", "", ""},
    {"adj", "funny", "drôle; comique", "", "976", "", ""},
    {"adj", "general", "général; répandu", "", "771", "", ""},
    {"adj", "German", "allemand", "", "838", "", ""},
    {"adj", "growing", "croissant; grandissant; qui augmente", "", "949", "", ""},
    {"adj", "heavy", "lourd; fort", "", "682", "", ""},
    {"adj", "hot", "chaud; épicé", "", "553", "", ""},
    {"adj", "human", "humain; de l'homme", "", "982", "", ""},
    {"adj", "interested", "intéressé", "", "876", "", ""},
    {"adj", "interesting", "intéressant", "", "548", "", ""},
    {"adj", "key", "clé; fondamental; essentiel", "", "843", "", ""},
    {"adj", "light", "léger; clair", "", "690", "", ""},
    {"adj", "lovely", "joli; charmant; délicieux", "", "833", "", ""},
    {"adj", "main", "principal; essentiel", "", "552", "", ""},
    {"adj", "middle", "du milieu; moyen", "", "759", "", ""},
    {"adj", "modern", "moderne", "", "701", "", ""},
    {"adj", "national", "national", "", "762", "", ""},
    {"adj", "necessary", "nécessaire; indispensable", "", "632", "", ""},
    {"adj", "past", "passé; ancien", "", "637", "", ""},
    {"adj", "popular", "populaire; célèbre", "", "656", "", ""},
    {"adj", "public", "public", "", "781", "", ""},
    {"adj", "quick", "rapide; prompt", "", "898", "", ""},
    {"adj", "quiet", "tranquille; silencieux", "", "882", "", ""},
    {"adj", "regular", "régulier; uni", "", "871", "", ""},
    {"adj", "rich", "riche; magnifique", "", "674", "", ""},
    {"adj", "Scottish", "écossais", "", "840", "", ""},
    {"adj", "serious", "sérieux; grave", "", "943", "", ""},
    {"adj", "sick", "malade; maladif", "", "993", "", ""},
    {"adj", "simple", "simple; élémentaire; facile", "", "778", "", ""},
    {"adj", "social", "social", "", "764", "", ""},
    {"adj", "soft", "doux; mou; ramolli", "", "844", "", ""},
    {"adj", "special", "spécial; particulier", "", "592", "", ""},
    {"adj", "tall", "grand; haut", "", "957", "", ""},
    {"adj", "total", "total; absolu", "", "984", "", ""},
    {"adj", "used", "habituel; d'occasion; usé", "", "951", "", ""},
    {"adj", "useful", "utile", "", "859", "", ""},
    {"adj", "warm", "chaud; chaleureux", "", "623", "", ""},
    {"adj", "wild", "sauvage; farouche", "", "920", "", ""},
    {"adj", "working", "de travail; actif; qui fonctionne", "", "824", "", ""},
    {"adj", "wrong", "faux; erroné; incorrect", "", "518", "", ""},
    {"adv adj", "alone", "seul", "", "940", "", ""},
    {"adv conj", " how", " comment", " tp_struct", "59", "", ""},
    {"adv conj", " then", " alors; à ce moment-là; ensuite; puis; donc", "", "45", "", ""},
    {"adv conj", "although", "bien que; malgré que", "", "675", "", ""},
    {"adv det", " most", " la plupart de; très fort; le plus", "", "130", "", ""},
    {"adv intrj", " of course", " naturellement; bien sûr; évidemment", "", "224", "", ""},
    {"adv part", " no", " non; aucun; aucune; pas de", "", "91", "", ""},
    {"adv prep", " after", " après; ci-après; derrière", " tp_struct", "70", "", ""},
    {"adv prep", " along", " le long de; sur; avec", " tp_struct", "428", "", ""},
    {"adv prep", " more", " plus; davantage de", " tp_struct tp_quantity", "83", "", ""},
    {"adv prep", " under", " sous; en dessous", " tp_struct", "164", "", ""},
    {"adv prep", " up", " en haut; au-dessus de", " tp_struct", "39", "", ""},
    {"adv prep", "above", "au-dessus; au-dessus de; par-dessus", "tp_struct", "528", "", ""},
    {"adv prep", "away from", "loin de", "", "599", "", ""},
    {"adv prep", "towards", "vers; envers", "tp_struct", "883", "", ""},
    {"adv pron", " much", " beaucoup", " tp_struct tp_quantity", "109", "", ""},
    {"adv", " about", " environ; à peu près; presque", " tp_struct", "110", "", ""},
    {"adv", " again", " encore; de nouveau", "", "120", "", ""},
    {"adv", " ago", " il y a", "", "302", "", ""},
    {"adv", " almost", " presque; près de", "", "241", "", ""},
    {"adv", " already", " déjà", "", "277", "", ""},
    {"adv", " also", " aussi; également", "", "100", "", ""},
    {"adv", " always", " toujours", "", "155", "", ""},
    {"adv", " around", " autour", "", "226", "", ""},
    {"adv", " as", " aussi; si", " tp_struct", "87", "", ""},
    {"adv", " at least", " au moins; du moins", "", "330", "", ""},
    {"adv", " away", " loin; au loin; partie", "", "150", "", ""},
    {"adv", " back", " en arrière; à l'arrière; de retour", "", "78", "", ""},
    {"adv", " before", " avant; auparavant; devant", " tp_struct", "328", "", ""},
    {"adv", " better", " mieux", "", "357", "", ""},
    {"adv", " down", " en bas; vers le bas", "", "75", "", ""},
    {"adv", " either", " non plus; l'un ou l'autre", "", "465", "", ""},
    {"adv", " else", " d'autre; autre", "", "380", "", ""},
    {"adv", " enough", " assez; suffisamment", " tp_struct", "278", "", ""},
    {"adv", " even", " même; voire; encore", "", "192", "", ""},
    {"adv", " ever", " jamais; toujours; un jour", "", "236", "", ""},
    {"adv", " finally", " enfin; finalement", "", "387", "", ""},
    {"adv", " first", " premièrement; d'abord", " tp_quantity tp_struct", "76", "", ""},
    {"adv", " for example", " par exemple", "", "287", "", ""},
    {"adv", " here", " ici", "", "84", "", ""},
    {"adv", " home", " à la maison", "", "228", "", ""},
    {"adv", " later", " plus tard; ensuite", "", "242", "", ""},
    {"adv", " long", " longuement; depuis longtemps", "", "303", "", ""},
    {"adv", " never", " jamais", "", "138", "", ""},
    {"adv", " not", " ne; non; pas", "", "18", "", ""},
    {"adv", " off", " loin; sans", "", "124", "", ""},
    {"adv", " often", " fréquemment; souvent", "", "296", "", ""},
    {"adv", " once", " une fois; jadis; autrefois", "", "322", "", ""},
    {"adv", " only", " seulement; ne ... que", "", "103", "", ""},
    {"adv", " out", " dehors; en dehors", "", "43", "", ""},
    {"adv", " perhaps", " peut-être que; peut-être", "", "455", "", ""},
    {"adv", " quite", " tout à fait; exactement", "", "214", "", ""},
    {"adv", " really", " vraiment; réellement", "", "271", "", ""},
    {"adv", " right", " directement; correctement; à droite", "", "169", "", ""},
    {"adv", " round", " autour; alentours", "", "443", "", ""},
    {"adv", " so", " si; tellement", "", "31", "", ""},
    {"adv", " sometimes", " quelquefois; parfois", "", "338", "", ""},
    {"adv", " soon", " bientôt; vite", "", "335", "", ""},
    {"adv", " still", " toujours; encore", "", "143", "", ""},
    {"adv", " there", " il y a; là", "", "26", "", ""},
    {"adv", " through", " à travers; par; pendant", "", "450", "", ""},
    {"adv", " today", " aujourd'hui; de nos jours", "", "210", "", ""},
    {"adv", " together", " ensemble; en même temps", "", "230", "", ""},
    {"adv", " too", " trop; aussi; en plus", "", "86", "", ""},
    {"adv", " very", " très", "", "44", "", ""},
    {"adv", " well", " bien", "", "69", "", ""},
    {"adv", " what", " ce que; quel; quelle; Quoi!", "", "46", "", ""},
    {"adv", " when", " quand; à quel moment", "", "93", "", ""},
    {"adv", " where", " où; là que", "", "107", "", ""},
    {"adv", " why", " pourquoi", "", "163", "", ""},
    {"adv", " yesterday", " hier", "", "313", "", ""},
    {"adv", " yet", " encore; jusque là", "", "389", "", ""},
    {"adv", "a bit", "un peu", "", "603", "", ""},
    {"adv", "a little", "un petit peu; un peu", "", "775", "", ""},
    {"adv", "a lot [of]", "beaucoup", "", "879", "", ""},
    {"adv", "anyway", "de toute façon; n'importe comment", "", "579", "", ""},
    {"adv", "as well", "aussi; aussi bien; également", "", "667", "", ""},
    {"adv", "at all", "du tout", "", "540", "", ""},
    {"adv", "below", "en bas; en dessous; au-dessous", "", "906", "", ""},
    {"adv", "best", "le mieux; le plus", "", "563", "", ""},
    {"adv", "certainly", "certainement; sûrement; bien sûr", "", "774", "", ""},
    {"adv", "close", "de près; près", "", "967", "", ""},
    {"adv", "early", "tôt; très tôt", "", "806", "", ""},
    {"adv", "easily", "facilement; aisément", "", "912", "", ""},
    {"adv", "especially", "particulièrement; notamment", "", "797", "", ""},
    {"adv", "generally", "généralement; en général", "", "933", "", ""},
    {"adv", "hard", "assidûment; durement", "", "752", "", ""},
    {"adv", "hardly", "à peine; rarement", "", "580", "", ""},
    {"adv", "instead", "plutôt", "", "718", "", ""},
    {"adv", "little", "peu; rarement", "", "855", "", ""},
    {"adv", "maybe", "peut-être que; peut-être", "", "570", "", ""},
    {"adv", "more than", "plus que", "", "542", "", ""},
    {"adv", "nearly", "presque; près de", "", "504", "", ""},
    {"adv", "no longer", "ne ... plus; pas plus", "", "971", "", ""},
    {"adv", "pretty", "assez", "", "801", "", ""},
    {"adv", "probably", "probablement; peut-être", "", "787", "", ""},
    {"adv", "quickly", "rapidement; vite", "", "672", "", ""},
    {"adv", "rather", "un peu; assez; plutôt", "", "846", "", ""},
    {"adv", "somewhere", "quelque part; environ", "", "928", "", ""},
    {"adv", "straight", "directement; tout droit", "", "919", "", ""},
    {"adv", "suddenly", "soudainement; subitement", "", "702", "", ""},
    {"adv", "surely", "sûrement; certainement", "", "842", "", ""},
    {"adv", "that", "si; aussi", "tp_struct", "707", "", ""},
    {"adv", "therefore", "donc; par conséquent", "", "886", "", ""},
    {"adv", "though", "quand même; pourtant", "tp_struct", "662", "", ""},
    {"adv", "tomorrow", "demain", "", "648", "", ""},
    {"adv", "tonight", "ce soir; cette nuit", "", "731", "", ""},
    {"adv", "usually", "habituellement; ordinairement", "", "619", "", ""},
    {"art", " a", " un; une", " tp_struct", "50", "erreur!", ""},
    {"br_adj", "whole", "tout; ensemble", "", "734", "", ""},
    {"conj adv", "however", "toutefois; néanmoins; cependant; pourtant", "tp_struct", "681", "", ""},
    {"conj obs", " for", " parce que; car", " tp_struct", "262", "", ""},
    {"conj prep", " rather than", " plutôt que", " tp_struct", "435", "", ""},
    {"conj prep", " since", " depuis; depuis que; puisque", " tp_struct", "274", "", ""},
    {"conj prep", " than", " que", " tp_struct", "113", "", ""},
    {"conj prep", " until", " jusqu'à; avant que", " tp_struct", "205", "", ""},
    {"conj", " after", " après que", " tp_struct", "191", "", ""},
    {"conj", " and", " et; aussi", " tp_struct", "2", "", ""},
    {"conj", " as if", " comme si", " tp_struct", "484", "", ""},
    {"conj", " as well as", " aussi bien que; en plus de", " tp_struct", "418", "", ""},
    {"conj", " as", " comme; alors que; tandis que", " tp_struct", "36", "", ""},
    {"conj", " because", " parce que", " tp_struct", "74", "", ""},
    {"conj", " before", " avant de", " tp_struct", "177", "", ""},
    {"conj", " but", " mais", " tp_struct", "23", "", ""},
    {"conj", " if", " si", " tp_struct", "49", "", ""},
    {"conj", " once", " une fois que; dès que", " tp_struct", "490", "", ""},
    {"conj", " or", " ou", " tp_struct", "53", "", ""},
    {"conj", " so that", " de sorte que; de façon que; afin que", " tp_struct", "431", "", ""},
    {"conj", " so", " de façon à ce que; pour que", " tp_struct", "156", "", ""},
    {"conj", " that", " que; afin que", " tp_struct", "12", "", ""},
    {"conj", " though", " bien que; quoique; encore que", " tp_struct", "342", "", ""},
    {"conj", " when", " quand; lorsque; au moment ou", " tp_struct", "30", "", ""},
    {"conj", " whether", " si; que", " tp_struct", "499", "", ""},
    {"conj", " while", " tant que; pendant que; bien que", " tp_struct", "129", "", ""},
    {"conj", "even if", "même si; même", "", "988", "", ""},
    {"det pron pl", " those", " ces; celles", " tp_struct", "185", "", ""},
    {"det", " the", " le; la; les", " tp_gen tp_struct", "1", "", ""},
    {"excl expr", " hello", " bonjour; salut; allô [téléphone]", "", "101", "", ""},
    {"expr", "in order to", "afin de; pour", "", "693", "", ""},
    {"interj part", " yes", " oui", "", "165", "", ""},
    {"intrj adv", " please", " s'il vous plaît; s'il te plaît", "", "375", "", ""},
    {"intrj", " sorry", " désolé; désolée", "", "472", "", ""},
    {"it_ex", "It is one {o'clock}.", "Il est une heure.", "", "916", "", ""},
    {"noun excl", "thanks", "remerciement; remerciements", "", "910", "", ""},
    {"noun inform", "dad", "père; papa", "", "651", "", ""},
    {"noun pl", " hair", " cheveux; cheveu; poil", "", "401", "", ""},
    {"noun pl", " others", " les autres; certains", "", "133", "", ""},
    {"noun pl", " terms", " conditions; dispositions", "", "354", "", ""},
    {"noun", " age", " âge; époque; vieillesse", "", "341", "", ""},
    {"noun", " air", " air; aspect", "", "323", "", ""},
    {"noun", " animal", " animal; bête", "", "430", "", ""},
    {"noun", " answer", " réponse; solution", "", "416", "", ""},
    {"noun", " art", " art; les arts", "", "379", "", ""},
    {"noun", " baby", " bébé", "", "458", "", ""},
    {"noun", " back", " dos; verso; derrière", "", "218", "", ""},
    {"noun", " ball", " balle; ballon", "", "494", "", ""},
    {"noun", " bank", " banque; grève", "", "363", "", ""},
    {"noun", " bed", " lit", "", "327", "", ""},
    {"noun", " bit", " morceau; bout; fragment", "", "477", "", ""},
    {"noun", " board", " planche; panneau d'affichage; table", "", "492", "", ""},
    {"noun", " body", " corps; organisme; organisation; carrosserie [voiture]", " tp_gen tp_law", "239", "", ""},
    {"noun", " book", " livre; bouquin", "", "171", "", ""},
    {"noun", " box", " boîte; caisse", "", "382", "", ""},
    {"noun", " boy", " garçon; gamin", "", "223", "", ""},
    {"noun", " Britain", " Grande-Bretagne", "", "255", "", ""},
    {"noun", " brother", " frère", "", "436", "", ""},
    {"noun", " building", " bâtiment; immeuble", "", "299", "", ""},
    {"noun", " business", " affaires; entreprise", "", "321", "", ""},
    {"noun", " car", " voiture; car; wagon", "", "172", "", ""},
    {"noun", " change", " changement; modification; monnaie", "", "343", "", ""},
    {"noun", " child", " enfant", "", "221", "", ""},
    {"noun", " Christmas", " Noël", "", "456", "", ""},
    {"noun", " church", " église", "", "282", "", ""},
    {"noun", " city", " ville; cité", "", "222", "", ""},
    {"noun", " class", " classe; cours; catégorie", "", "293", "", ""},
    {"noun", " club", " club; trèfle; bâton", "", "398", "", ""},
    {"noun", " company", " entreprise; société; compagnie", "", "265", "", ""},
    {"noun", " cost", " coût; prix", "", "395", "", ""},
    {"noun", " country", " pays; État", "", "152", "", ""},
    {"noun", " course", " cours", "", "337", "", ""},
    {"noun", " day", " jour; journée", "", "65", "", ""},
    {"noun", " death", " mort; décès", " tp_law", "444", "", ""},
    {"noun", " director", " directeur; réalisateur", "", "446", "", ""},
    {"noun", " doctor", " médecin; docteur", "", "407", "", ""},
    {"noun", " dog", " chien", "", "353", "", ""},
    {"noun", " door", " porte; portière", "", "201", "", ""},
    {"noun", " end", " fin; terme; extrémité", "", "200", "", ""},
    {"noun", " England", " Angleterre", "", "319", "", ""},
    {"noun", " Europe", " Europe", "", "391", "", ""},
    {"noun", " evening", " soirée; soir", "", "473", "", ""},
    {"noun", " eye", " oeil; oeillet; œil; yeux", "", "350", "", ""},
    {"noun", " face", " visage; figure", "", "284", "", ""},
    {"noun", " fact", " fait; réalité", "", "434", "", ""},
    {"noun", " family", " famille; foyer", "", "206", "", ""},
    {"noun", " father", " père", "", "195", "", ""},
    {"noun", " feeling", " sentiment; sensation", "", "479", "", ""},
    {"noun", " field", " champ; terrain", "", "367", "", ""},
    {"noun", " fire", " feu; incendie", "", "356", "", ""},
    {"noun", " floor", " sol; fond; plancher", "", "403", "", ""},
    {"noun", " food", " nourriture; aliment", "", "309", "", ""},
    {"noun", " foot", " pied; patte", "", "336", "", ""},
    {"noun", " form", " forme; formulaire; genre", "", "355", "", ""},
    {"noun", " friend", " ami; copain", "", "134", "", ""},
    {"noun", " game", " jeu; match", "", "276", "", ""},
    {"noun", " garden", " jardin", "", "405", "", ""},
    {"noun", " girl", " fille; copine", "", "196", "", ""},
    {"noun", " God", " Dieu; Seigneur", "", "467", "", ""},
    {"noun", " Great Britain", " Grande-Bretagne", "", "421", "", ""},
    {"noun", " ground", " sol; terre; terrain", "", "312", "", ""},
    {"noun", " group", " groupe", "", "385", "", ""},
    {"noun", " hand", " main", "", "194", "", ""},
    {"noun", " head", " tête; pointe", "", "183", "", ""},
    {"noun", " health", " santé; prospérité", "", "369", "", ""},
    {"noun", " heart", " cœur;coeur", "", "500", "", ""},
    {"noun", " help", " aide; assistance", "", "396", "", ""},
    {"noun", " home", " maison; domicile; habitation", "", "116", "", ""},
    {"noun", " horse", " cheval", "", "475", "", ""},
    {"noun", " hospital", " hôpital", "", "381", "", ""},
    {"noun", " hour", " heure", "", "315", "", ""},
    {"noun", " house", " maison", "", "96", "", ""},
    {"noun", " idea", " idée; notion", "", "474", "", ""},
    {"noun", " job", " emploi; poste; travail", "", "310", "", ""},
    {"noun", " kind", " genre; espèce; sorte", "", "240", "", ""},
    {"noun", " land", " terre; sol; pays", "", "252", "", ""},
    {"noun", " law", " droit; loi; justice", "", "468", "", ""},
    {"noun", " light", " lumière; lampe; lueur", "", "383", "", ""},
    {"noun", " line", " ligne; trait; file", "", "281", "", ""},
    {"noun", " London", " Londres", "", "199", "", ""},
    {"noun", " look", " regard", "", "419", "", ""},
    {"noun", " lot", " sort; destinée; lot; parcelle", "", "231", "", ""},
    {"noun", " love", " amour; charité", "", "331", "", ""},
    {"noun", " man", " homme; personne", "", "82", "", ""},
    {"noun", " market", " marché; clientèle", "", "414", "", ""},
    {"noun", " matter", " matière; question; affaire", "", "461", "", ""},
    {"noun", " May", " mai", "", "348", "", ""},
    {"noun", " mind", " esprit; raison", "", "372", "", ""},
    {"noun", " minute", " minute; moment", "", "388", "", ""},
    {"noun", " money", " argent; monnaie", "", "189", "", ""},
    {"noun", " month", " mois", "", "264", "", ""},
    {"noun", " morning", " matin; matinée", "", "225", "", ""},
    {"noun", " mother", " mère", "", "142", "", ""},
    {"noun", " Mr", " Monsieur; M", "", "148", "", ""},
    {"noun", " Mrs", " Mme; Madame", "", "307", "", ""},
    {"noun", " music", " musique", "", "449", "", ""},
    {"noun", " name", " nom", "", "145", "", ""},
    {"noun", " need", " besoin; nécessité", "", "292", "", ""},
    {"noun", " news", " nouvelle; information", "", "437", "", ""},
    {"noun", " night", " nuit", "", "122", "", ""},
    {"noun", " north", " Nord", "", "471", "", ""},
    {"noun", " number", " nombre; numéro", "", "325", "", ""},
    {"noun", " office", " bureau; service; fonction", "", "344", "", ""},
    {"noun", " one", " un; une; homme", " tp_struct tp_quantity", "345", "", ""},
    {"noun", " paper", " papier; feuille; journal; essai", "", "243", "", ""},
    {"noun", " park", " parc; jardin public", "", "496", "", ""},
    {"noun", " part", " partie; fraction; piece", "", "176", "", ""},
    {"noun", " party", " partie; parti [pol]; fête; réception", "", "170", "", ""},
    {"noun", " people", " peuple; gens; personnes", "", "73", "", ""},
    {"noun", " per cent", " pour cent", "", "181", "", ""},
    {"noun", " person", " personne; individu", "", "433", "", ""},
    {"noun", " picture", " image; photo; peinture", "", "346", "", ""},
    {"noun", " piece", " morceau; part; tranche", "", "486", "", ""},
    {"noun", " place", " endroit; lieu; coin", "", "128", "", ""},
    {"noun", " plant", " plante; installation", "", "393", "", ""},
    {"noun", " police", " police", "", "423", "", ""},
    {"noun", " power", " pouvoir; puissance; influence; force", "", "279", "", ""},
    {"noun", " relationship", " liens de parenté; rapports; relations", "", "480", "", ""},
    {"noun", " report", " rapport; communiqué", "", "347", "", ""},
    {"noun", " research", " recherche; étude", "", "406", "", ""},
    {"noun", " rest", " repos; sieste; reste", "", "447", "", ""},
    {"noun", " right", " droite; droit; bien", "", "190", "", ""},
    {"noun", " river", " rivière; fleuve", "", "420", "", ""},
    {"noun", " road", " route; chemin", "", "244", "", ""},
    {"noun", " room", " pièce; chambre; salle", "", "154", "", ""},
    {"noun", " school", " école", "", "77", "", ""},
    {"noun", " sea", " mer; océan", "", "409", "", ""},
    {"noun", " set", " collection; ensemble; service", "", "365", "", ""},
    {"noun", " show", " représentation; manifestation", "", "438", "", ""},
    {"noun", " side", " côté; flanc; aspect", "", "178", "", ""},
    {"noun", " sister", " soeur; bonne soeur; infirmière; sœur", "", "478", "", ""},
    {"noun", " son", " fils", "", "432", "", ""},
    {"noun", " story", " histoire; conte; récit", "", "280", "", ""},
    {"noun", " street", " rue", "", "273", "", ""},
    {"noun", " study", " bureau; étude; recherche", "", "250", "", ""},
    {"noun", " summer", " été", "", "463", "", ""},
    {"noun", " sun", " soleil", "", "451", "", ""},
    {"noun", " table", " table; liste", "", "305", "", ""},
    {"noun", " teacher", " professeur; enseignant", "", "261", "", ""},
    {"noun", " test", " test; essai; examen", "", "445", "", ""},
    {"noun", " thing", " chose; truc", "", "119", "", ""},
    {"noun", " thought", " pensée; idée", "", "339", "", ""},
    {"noun", " time", " temps; fois", "", "37", "", ""},
    {"noun", " town", " ville; commune", "", "247", "", ""},
    {"noun", " tree", " arbre", "", "306", "", ""},
    {"noun", " use", " utilisation", "", "213", "", ""},
    {"noun", " wall", " mur; muraille", "", "429", "", ""},
    {"noun", " war", " guerre; querelle", "", "251", "", ""},
    {"noun", " water", " eau; eaux; mer", "", "139", "", ""},
    {"noun", " way", " chemin", "", "94", "", ""},
    {"noun", " week", " semaine", "", "159", "", ""},
    {"noun", " wife", " femme; épouse", "", "394", "", ""},
    {"noun", " window", " fenêtre; vitrine", "", "314", "", ""},
    {"noun", " woman", " femme", "", "219", "", ""},
    {"noun", " word", " mot", "", "257", "", ""},
    {"noun", " work", " travail; oeuvre; emploi;œuvre", "", "111", "", ""},
    {"noun", " world", " monde; univers", "", "184", "", ""},
    {"noun", " year", " an; année", "", "88", "", ""},
    {"noun", "accident", "accident; hasard", "", "813", "", ""},
    {"noun", "account", "compte; compte rendu", "", "961", "", ""},
    {"noun", "action", "action; mesure; acte", "", "677", "", ""},
    {"noun", "address", "adresse; discours", "", "888", "", ""},
    {"noun", "afternoon", "après-midi", "", "565", "", ""},
    {"noun", "America", "Amérique", "", "793", "", ""},
    {"noun", "amount", "quantité; nombre; montant", "", "925", "", ""},
    {"noun", "April", "avril", "", "962", "", ""},
    {"noun", "area", "région; zone; secteur", "", "636", "", ""},
    {"noun", "arm", "bras", "", "507", "", ""},
    {"noun", "army", "armée", "", "566", "", ""},
    {"noun", "artist", "artiste", "", "827", "", ""},
    {"noun", "attack", "attaque; agression", "", "948", "", ""},
    {"noun", "attention", "attention", "", "751", "", ""},
    {"noun", "bag", "sachet; sac; valise", "", "735", "", ""},
    {"noun", "band", "bande; ruban; groupe [mus]", "", "640", "", ""},
    {"noun", "bar", "bar; barre; planche; lingot; barre d'un tribunal", "tp_eat tp_law", "921", "", ""},
    {"noun", "base", "base; socle", "", "643", "", ""},
    {"noun", "basis", "base; principe", "", "543", "", ""},
    {"noun", "bedroom", "chambre à coucher", "", "979", "", ""},
    {"noun", "beginning", "début; commencement; départ", "", "989", "", ""},
    {"noun", "behaviour", "comportement; conduite", "", "740", "", ""},
    {"noun", "bill", "facture; addition; projet de loi; bec", "tp_gen tp_law", "562", "", ""},
    {"noun", "bird", "oiseau", "", "10000", "", ""},
    {"noun", "boat", "bateau; navire", "", "763", "", ""},
    {"noun", "bottle", "bouteille", "", "953", "", ""},
    {"noun", "bottom", "bas; fond; derrière", "", "890", "", ""},
    {"noun", "bridge", "pont; passerelle", "", "823", "", ""},
    {"noun", "bus", "car; autobus; bus", "", "850", "", ""},
    {"noun", "call", "appel; demande", "", "591", "", ""},
    {"noun", "capital", "capitale; majuscule", "", "644", "", ""},
    {"noun", "care", "soin; attention", "", "834", "", ""},
    {"noun", "case", "cas; sacoche; affaire [jur]; procès; cause", "tp_gen tp_law", "653", "", ""},
    {"noun", "cause", "cause; raison", "", "613", "", ""},
    {"noun", "cell", "cellule", "", "880", "", ""},
    {"noun", "centre", "centre; milieu", "", "659", "", ""},
    {"noun", "century", "siècle", "", "942", "", ""},
    {"noun", "chair", "chaise; fauteuil", "", "639", "", ""},
    {"noun", "chance", "hasard; chance; occasion", "", "502", "", ""},
    {"noun", "charge", "accusation; inculpation; charge", "tp_gen tp_law", "992", "", ""},
    {"noun", "clothes", "habits; vêtements", "", "918", "", ""},
    {"noun", "coffee", "café", "tp_eat", "874", "", ""},
    {"noun", "colour", "couleur; teint", "", "622", "", ""},
    {"noun", "community", "communauté; collectivité", "", "766", "", ""},
    {"noun", "condition", "condition; état", "", "710", "", ""},
    {"noun", "control", "contrôle; régulation; vérification", "", "889", "", ""},
    {"noun", "copy", "copie; exemplaire", "", "822", "", ""},
    {"noun", "corner", "coin; angle", "", "809", "", ""},
    {"noun", "council", "conseil", "", "902", "", ""},
    {"noun", "county", "comté; département", "", "722", "", ""},
    {"noun", "court", "tribunal; cour; terrain", "tp_law", "755", "", ""},
    {"noun", "cup", "tasse; coupe", "", "649", "", ""},
    {"noun", "cut", "coupure; coupe; incision", "", "765", "", ""},
    {"noun", "date", "date; rendez-vous; rancard", "", "556", "", ""},
    {"noun", "daughter", "fille", "", "750", "", ""},
    {"noun", "difference", "différence; écart", "", "773", "", ""},
    {"noun", "dinner", "dîner; souper", "", "595", "", ""},
    {"noun", "dream", "rêve; rêverie", "", "947", "", ""},
    {"noun", "dress", "robe; tenue; vêtements", "", "913", "", ""},
    {"noun", "drink", "boisson; coup", "", "686", "", ""},
    {"noun", "ear", "oreille; ouïe; épi", "", "983", "", ""},
    {"noun", "earth", "monde; terre; sol", "", "732", "", ""},
    {"noun", "east", "Est; Orient", "", "569", "", ""},
    {"noun", "employee", "employé; employée; travailleur", "", "952", "", ""},
    {"noun", "energy", "énergie; vitalité", "", "744", "", ""},
    {"noun", "exercise", "exercice; pratique", "", "841", "", ""},
    {"noun", "experience", "expérience", "", "803", "", ""},
    {"noun", "fall", "chute; baisse; automne [Am]", "", "941", "", ""},
    {"noun", "farm", "ferme", "", "642", "", ""},
    {"noun", "farmer", "paysan; agriculteur", "", "799", "", ""},
    {"noun", "finger", "doigt", "", "728", "", ""},
    {"noun", "fish", "poisson", "", "687", "", ""},
    {"noun", "flat", "plat; appartement", "", "900", "", ""},
    {"noun", "flower", "fleur", "", "924", "", ""},
    {"noun", "football", "football [GB]; football américain [US]", "", "761", "", ""},
    {"noun", "force", "force; violence", "", "946", "", ""},
    {"noun", "forest", "forêt", "", "754", "", ""},
    {"noun", "France", "France", "", "578", "", ""},
    {"noun", "French", "français [langue]", "", "650", "", ""},
    {"noun", "front", "front; devant; façade", "", "670", "", ""},
    {"noun", "gas", "gaz; carburant [US]; essence [US]", "", "635", "", ""},
    {"noun", "Germany", "Allemagne", "", "741", "", ""},
    {"noun", "glass", "verre; verrière", "", "560", "", ""},
    {"noun", "gold", "or", "", "917", "", ""},
    {"noun", "government", "gouvernement; cabinet", "", "612", "", ""},
    {"noun", "gun", "pistolet; fusil; canon", "", "875", "", ""},
    {"noun", "hill", "colline; hauteur", "", "602", "", ""},
    {"noun", "history", "histoire", "", "555", "", ""},
    {"noun", "hole", "trou; orifice; terrier", "", "641", "", ""},
    {"noun", "holiday", "vacances; congé", "", "610", "", ""},
    {"noun", "hope", "espoir; espérance", "", "537", "", ""},
    {"noun", "hotel", "hôtel", "", "664", "", ""},
    {"noun", "husband", "mari; époux", "", "848", "", ""},
    {"noun", "industry", "industrie", "", "594", "", ""},
    {"noun", "interest", "intérêt", "", "748", "", ""},
    {"noun", "Ireland", "Irlande", "", "870", "", ""},
    {"noun", "island", "île; îlot", "", "770", "", ""},
    {"noun", "key", "clé; clef; touche", "", "887", "", ""},
    {"noun", "king", "roi", "", "633", "", ""},
    {"noun", "kitchen", "cuisine", "", "617", "", ""},
    {"noun", "lady", "dame; femme", "", "585", "", ""},
    {"noun", "language", "langue; langage", "", "557", "", ""},
    {"noun", "leader", "chef; directeur", "", "769", "", ""},
    {"noun", "leg", "jambe; patte; pied", "", "663", "", ""},
    {"noun", "letter", "lettre; caractère", "", "694", "", ""},
    {"noun", "level", "niveau", "", "768", "", ""},
    {"noun", "life", "vie; existence", "", "505", "", ""},
    {"noun", "list", "liste", "", "847", "", ""},
    {"noun", "machine", "machine; engin", "", "529", "", ""},
    {"noun", "mark", "marque; cible", "", "973", "", ""},
    {"noun", "master", "maître; professeur", "", "930", "", ""},
    {"noun", "match", "allumette; jeu; match; partie", "", "739", "", ""},
    {"noun", "material", "substance; matière; tissu", "", "590", "", ""},
    {"noun", "means", "moyens; ressources", "", "788", "", ""},
    {"noun", "measure", "mesure; unité de mesure; règle", "", "986", "", ""},
    {"noun", "meeting", "rencontre; réunion", "", "608", "", ""},
    {"noun", "member", "membre; adhérent", "", "586", "", ""},
    {"noun", "memory", "mémoire; souvenir", "", "704", "", ""},
    {"noun", "message", "message; course", "", "802", "", ""},
    {"noun", "method", "méthode", "", "796", "", ""},
    {"noun", "middle", "milieu; centre", "", "873", "", ""},
    {"noun", "mile", "mile", "", "624", "", ""},
    {"noun", "million", "million", "tp_quantity", "703", "", ""},
    {"noun", "Miss", "Mademoiselle", "", "527", "", ""},
    {"noun", "model", "mannequin; modèle; maquette", "", "726", "", ""},
    {"noun", "moment", "moment; instant", "", "829", "", ""},
    {"noun", "mountain", "montagne", "", "987", "", ""},
    {"noun", "mouth", "bouche; gueule", "", "627", "", ""},
    {"noun", "move", "mouvement; déménagement", "", "607", "", ""},
    {"noun", "nature", "nature; essence; caractère", "", "539", "", ""},
    {"noun", "neck", "cou; nuque; goulot", "", "931", "", ""},
    {"noun", "newspaper", "journal; quotidien", "", "758", "", ""},
    {"noun", "noise", "bruit; son", "", "905", "", ""},
    {"noun", "note", "note; annotation", "", "800", "", ""},
    {"noun", "officer", "officier; fonctionnaire", "", "671", "", ""},
    {"noun", "oil", "pétrole; huile", "", "550", "", ""},
    {"noun", "order", "ordre; commande", "", "531", "", ""},
    {"noun", "organisation", "organisation; structure", "", "657", "", ""},
    {"noun", "page", "page", "", "549", "", ""},
    {"noun", "pair", "paire; couple", "", "668", "", ""},
    {"noun", "past", "passé", "", "684", "", ""},
    {"noun", "period", "période; époque", "", "605", "", ""},
    {"noun", "plan", "plan; projet", "", "536", "", ""},
    {"noun", "planning", "planification; préparation", "", "891", "", ""},
    {"noun", "plate", "assiette; plat", "", "966", "", ""},
    {"noun", "play", "jeu; divertissement", "", "526", "", ""},
    {"noun", "player", "joueur; acteur", "", "857", "", ""},
    {"noun", "point", "pointe; point", "", "700", "", ""},
    {"noun", "population", "population", "", "994", "", ""},
    {"noun", "position", "position; situation; poste [de travail]", "", "727", "", ""},
    {"noun", "possibility", "possibilité", "", "864", "", ""},
    {"noun", "post", "poste; poteau", "", "785", "", ""},
    {"noun", "pound", "livre [monnaie anglaise, poids]", "", "647", "", ""},
    {"noun", "practice", "pratique; coutume; habitude", "", "860", "", ""},
    {"noun", "present", "cadeau; présent", "", "975", "", ""},
    {"noun", "president", "président", "", "625", "", ""},
    {"noun", "price", "prix", "", "571", "", ""},
    {"noun", "problem", "problème", "", "858", "", ""},
    {"noun", "process", "processus; procédé; procès [droit]", "", "596", "", ""},
    {"noun", "project", "projet; plan", "", "927", "", ""},
    {"noun", "proposal", "proposition; suggestion", "", "699", "", ""},
    {"noun", "pupil", "élève; pupille", "", "903", "", ""},
    {"noun", "purpose", "but; objet; intention", "", "807", "", ""},
    {"noun", "quarter", "quart; trimestre", "", "745", "", ""},
    {"noun", "queen", "reine", "", "937", "", ""},
    {"noun", "question", "question; doute", "", "544", "", ""},
    {"noun", "race", "course; race", "", "601", "", ""},
    {"noun", "radio", "poste de radio; radio", "", "716", "", ""},
    {"noun", "rain", "pluie", "", "733", "", ""},
    {"noun", "rate", "taux; tarif; rythme", "", "683", "", ""},
    {"noun", "reading", "lecture; leçon; interprétation", "", "863", "", ""},
    {"noun", "reason", "raison; motif", "", "512", "", ""},
    {"noun", "record", "témoignage; enregistrement; disque", "", "743", "", ""},
    {"noun", "region", "région", "", "981", "", ""},
    {"noun", "response", "réponse", "", "782", "", ""},
    {"noun", "result", "résultat; conséquence", "", "964", "", ""},
    {"noun", "return", "retour; renvoi [tennis]; rapport [profi]", "", "885", "", ""},
    {"noun", "rock", "roche; rocher; rock", "", "719", "", ""},
    {"noun", "row", "rang; rangée; querelle", "", "899", "", ""},
    {"noun", "rule", "règle; règlement", "", "725", "", ""},
    {"noun", "run", "course; fuite", "", "646", "", ""},
    {"noun", "safety", "sécurité; sûreté", "", "980", "", ""},
    {"noun", "sale", "vente; solde", "", "655", "", ""},
    {"noun", "scene", "scène; lieu; décor", "", "990", "", ""},
    {"noun", "science", "science", "", "736", "", ""},
    {"noun", "Scotland", "Écosse", "", "698", "", ""},
    {"noun", "season", "saison", "", "738", "", ""},
    {"noun", "seat", "siège; place; siège parlementaire", "tp_law", "676", "", ""},
    {"noun", "second", "seconde", "", "533", "", ""},
    {"noun", "secretary", "secrétaire", "", "618", "", ""},
    {"noun", "section", "section; partie; tronçon", "", "897", "", ""},
    {"noun", "sentence", "sentence; phrase; peine", "tp_law", "712", "", ""},
    {"noun", "ship", "bateau; navire", "", "660", "", ""},
    {"noun", "shop", "magasin; boutique", "", "508", "", ""},
    {"noun", "shot", "coup; coup de feu", "", "960", "", ""},
    {"noun", "sign", "signe; geste", "", "573", "", ""},
    {"noun", "Sir", "Monsieur; Sir", "", "631", "", ""},
    {"noun", "size", "taille; dimension", "", "547", "", ""},
    {"noun", "skin", "peau", "", "747", "", ""},
    {"noun", "sky", "ciel", "", "944", "", ""},
    {"noun", "smile", "sourire", "", "922", "", ""},
    {"noun", "sort", "genre; sorte; espèce", "", "777", "", ""},
    {"noun", "sound", "son; bruit", "", "577", "", ""},
    {"noun", "south", "Sud", "", "503", "", ""},
    {"noun", "space", "espace; écart; place", "", "856", "", ""},
    {"noun", "speed", "vitesse; rapidité", "", "830", "", ""},
    {"noun", "sport", "sport", "", "955", "", ""},
    {"noun", "spring", "printemps; bond; ressort; source", "", "717", "", ""},
    {"noun", "stage", "scène; estrade", "", "587", "", ""},
    {"noun", "standard", "norme; critères ; bannière; étendard", "", "908", "", ""},
    {"noun", "star", "étoile; vedette; star", "", "792", "", ""},
    {"noun", "start", "début; commencement; départ", "", "654", "", ""},
    {"noun", "state", "état; Etat", "", "666", "", ""},
    {"noun", "statement", "exposition; déclaration; affirmation; déposition", "tp_gen tp_law tp_politics", "878", "", ""},
    {"noun", "station", "station; poste; gare", "", "525", "", ""},
    {"noun", "step", "pas; étape; marchepied", "", "567", "", ""},
    {"noun", "stone", "pierre; caillou", "", "614", "", ""},
    {"noun", "store", "entrepôt; réserve; stockage", "", "756", "", ""},
    {"noun", "structure", "structure; construction", "", "711", "", ""},
    {"noun", "subject", "sujet; matière [étude]", "", "811", "", ""},
    {"noun", "system", "système; structure", "", "695", "", ""},
    {"noun", "talk", "conversation; causerie; exposé", "", "581", "", ""},
    {"noun", "tax", "taxe; impôt", "", "963", "", ""},
    {"noun", "tea", "thé", "", "865", "", ""},
    {"noun", "team", "équipe", "", "538", "", ""},
    {"noun", "telephone", "téléphone", "", "815", "", ""},
    {"noun", "term", "periode; terme; condition", "tp_gen tp_law", "832", "", ""},
    {"noun", "title", "titre; droit; titre de propriété; titre nobiliaire", "tp_gen tp_law", "972", "", ""},
    {"noun", "top", "haut; tête; sommet", "", "521", "", ""},
    {"noun", "track", "trace; chemin; piste", "", "812", "", ""},
    {"noun", "trade", "commerce; échange commercial", "", "630", "", ""},
    {"noun", "train", "train; rame", "", "600", "", ""},
    {"noun", "training", "formation; éducation", "", "669", "", ""},
    {"noun", "trip", "voyage; excursion", "", "851", "", ""},
    {"noun", "trouble", "gêne; ennui; problème", "", "576", "", ""},
    {"noun", "turn", "tour; virage; tournure", "", "724", "", ""},
    {"noun", "type", "type; genre", "", "658", "", ""},
    {"noun", "union", "union; association; syndicat", "", "893", "", ""},
    {"noun", "user", "utilisateur; usager", "", "790", "", ""},
    {"noun", "value", "valeur; mérite", "", "634", "", ""},
    {"noun", "view", "vue; avis; opinion", "", "909", "", ""},
    {"noun", "village", "village; bourgade", "", "606", "", ""},
    {"noun", "visit", "visite; séjour", "", "523", "", ""},
    {"noun", "voice", "voix", "", "679", "", ""},
    {"noun", "Wales", "Pays de Galles", "", "901", "", ""},
    {"noun", "walk", "promenade; marche à pied", "", "896", "", ""},
    {"noun", "weather", "temps", "", "849", "", ""},
    {"noun", "weight", "poids; pesanteur", "", "974", "", ""},
    {"noun", "West", "Ouest; Occident", "", "620", "", ""},
    {"noun", "while", "instant", "tp_struct", "604", "", ""},
    {"noun", "will", "volonté; testament", "", "760", "", ""},
    {"noun", "wind", "vent; souffle", "", "746", "", ""},
    {"noun", "winter", "hiver", "", "696", "", ""},
    {"noun", "wood", "bois; taillis", "", "978", "", ""},
    {"noun", "worker", "ouvrier; travailleur", "", "821", "", ""},
    {"noun", "writing", "écriture; orthographe", "", "661", "", ""},
    {"num", " eight", " huit", " tp_struct tp_quantity", "368", "", ""},
    {"num", " five", " cinq", " tp_struct tp_quantity", "174", "", ""},
    {"num", " four", " quatre", " tp_struct tp_quantity", "144", "", ""},
    {"num", " hundred", " cent", " tp_struct tp_quantity", "493", "", ""},
    {"num", " one", " un; une", " tp_struct tp_quantity", "29", "", ""},
    {"num", " seven", " sept", " tp_struct tp_quantity", "366", "", ""},
    {"num", " six", " six", " tp_struct tp_quantity", "216", "", ""},
    {"num", " ten", " dix", " tp_struct tp_quantity", "275", "", ""},
    {"num", " three", " trois", " tp_struct tp_quantity", "99", "", ""},
    {"num", " twenty", " vingt", " tp_struct tp_quantity", "397", "", ""},
    {"num", " two", " deux", " tp_struct tp_quantity", "57", "", ""},
    {"num", "fifty", "cinquante", "tp_quantity", "831", "", ""},
    {"num", "nine", "neuf", "tp_struct tp_quantity", "794", "", ""},
    {"num", "seventeen", "dix-sept", "tp_quantity", "10000", "", ""},
    {"num", "third", "troisième", "tp_quantity tp_struct", "530", "", ""},
    {"num", "thirty", "trente; trentième", "tp_quantity", "795", "", ""},
    {"num", "thousand", "mille", "tp_quantity tp_struct", "749", "", ""},
    {"num", "twelve", "douze", "tp_quantity", "808", "", ""},
    {"prep", " about", " sur; au sujet de", " tp_struct", "51", "", ""},
    {"prep", " according to", " selon; d'après", " tp_struct", "488", "", ""},
    {"prep", " across", " à travers; de l'autre côté", " tp_struct", "260", "", ""},
    {"prep", " adv", " in", " dans; en; à; dedans", " tp_struct", "4", ""},
    {"prep", " adv", " over", " sur; par dessus; plus de", " tp_struct", "98", ""},
    {"prep", " against", " contre; en échange de", " tp_struct", "320", "", ""},
    {"prep", " around", " autour de; à peu près; environ", "", "209", "", ""},
    {"prep", " at", " à; chez; vers", " tp_space tp_struct", "21", "", ""},
    {"prep", " because of", " à cause de; en raison de", " tp_struct", "400", "", ""},
    {"prep", " behind", " derrière; en arrière de", " tp_struct", "358", "", ""},
    {"prep", " between", " entre", " tp_struct", "212", "", ""},
    {"prep", " by", " par; en; près de", " tp_struct", "48", "", ""},
    {"prep", " down", " vers le bas; plus bas", "", "376", "", ""},
    {"prep", " during", " pendant; au cours de", " tp_struct", "483", "", ""},
    {"prep", " for", " pour; depuis; pendant", " tp_struct", "10", "", ""},
    {"prep", " from", " de; dès; à partir de", " tp_struct", "25", "", ""},
    {"prep", " into", " dans; en; dedans", " tp_struct", "68", "", ""},
    {"prep", " like", " comme", " tp_struct", "58", "", ""},
    {"prep", " near", " près de; auprès de", "", "452", "", ""},
    {"prep", " of", " de; pour", " tp_gen tp_struct", "3", "", ""},
    {"prep", " off", " au large de; à coté de; hors de; en dehors de", " tp_struct", "234", "", ""},
    {"prep", " on", " sur; à; par", " tp_struct", "13", "", ""},
    {"prep", " out of", " hors de; à bout de", " tp_struct", "136", "", ""},
    {"prep", " to", " à; chez; en; jusqu'à", " tp_struct", "5", "", ""},
    {"prep", " upon", " sur; à; contre", " tp_struct", "288", "", ""},
    {"prep", " with", " avec; à", "", "16", "", ""},
    {"prep", " without", " sans", " tp_struct", "235", "", ""},
    {"prep", "among", "parmi; chez; entre", "tp_struct", "559", "", ""},
    {"prep", "beside", "à côté de; auprès de; d'ailleurs", "", "991", "", ""},
    {"prep", "in terms of", "en fonction de; du point de vue de; en termes de", "", "810", "", ""},
    {"prep", "inside", "dans; à l'intérieur de", "", "689", "", ""},
    {"prep", "onto", "sur", "", "923", "", ""},
    {"prep", "past", "au-delà de", "", "852", "", ""},
    {"prep", "round", "autour de; environ", "", "532", "", ""},
    {"prep", "within", "dans; à l'intérieur de", "tp_struct", "798", "", ""},
    {"prepphr", "up to", "jusqu'à", "tp_struct", "511", "", ""},
    {"pron det", " whose", " dont; de qui; duquel", " tp_struct", "415", "", ""},
    {"pron pl", " these", " ces", " tp_struct", "115", "", ""},
    {"pron pl", " they", " ils; elles; eux", " tp_struct", "14", "", ""},
    {"pron", " anything", " quelque chose; n'importe quoi", " tp_struct", "248", "", ""},
    {"pron", " everything", " tout", " tp_struct", "361", "", ""},
    {"pron", " he", " il; lui", " tp_struct", "9", "", ""},
    {"pron", " her", " la; sa; son", " tp_struct", "38", "", ""},
    {"pron", " him", " le; lui", "", "50", "", ""},
    {"pron", " himself", " lui-même; se", " tp_struct", "316", "", ""},
    {"pron", " his", " sa; son; le sien; la sienne", " tp_struct", "32", "", ""},
    {"pron", " I", " je; moi", " tp_struct", "85", "", ""},
    {"pron", " it", " ça; le; la", " tp_struct", "6", "", ""},
    {"pron", " its", " son; sa; ses", " tp_struct", "125", "", ""},
    {"pron", " my", " mon; ma; mes", " tp_struct", "28", "", ""},
    {"pron", " myself", " me; moi; moi-même", " tp_struct", "454", "", ""},
    {"pron", " nothing", " rien", " tp_struct", "291", "", ""},
    {"pron", " our", " notre; nos", " tp_struct", "60", "", ""},
    {"pron", " she", " elle; celle", " tp_struct", "15", "", ""},
    {"pron", " someone", " quelqu'un", " tp_struct", "439", "", ""},
    {"pron", " something", " quelque chose", " tp_struct", "141", "", ""},
    {"pron", " that", " ce; cet; cette; ces; cela; que; qui", " tp_struct", "17", "", ""},
    {"pron", " their", " leur; leurs", " tp_struct", "52", "", ""},
    {"pron", " this", " ce; cette; ceci", " tp_struct", "22", "", ""},
    {"pron", " we", " nous; on", " tp_struct", "11", "", ""},
    {"pron", " which", " quel; quelle; qui; que", " tp_struct", "64", "", ""},
    {"pron", " who", " qui; ceux; celles", " tp_struct", "71", "", ""},
    {"pron", " you", " tu; toi; vous; te", " tp_struct", "8", "", ""},
    {"pron", " your", " ton; votre", " tp_struct", "41", "", ""},
    {"pron", "anyone", "quelqu'un; n'importe qui; personne", "tp_struct", "517", "", ""},
    {"pron", "each other", "l'un l'autre; les uns les autres", "", "729", "", ""},
    {"pron", "everybody", "chacun; tout le monde", "", "839", "", ""},
    {"pron", "everyone", "chacun; tout le monde", "tp_struct", "575", "", ""},
    {"pron", "herself", "se; elle-même", "tp_struct", "945", "", ""},
    {"pron", "itself", "lui-même; elle-même", "tp_struct", "895", "", ""},
    {"pron", "lots", "beaucoup; les masses", "", "959", "", ""},
    {"pron", "none", "aucun; personne", "", "776", "", ""},
    {"pron", "somebody", "quelqu'un", "", "837", "", ""},
    {"v v/ireg", " hold", " tenir; maintenir", "", "238", "", ""},
    {"v v/ireg", " to ask", " demander; interroger", "", "198", "", ""},
    {"v v/ireg", " to be", " être", " tp_gen", "20", "", ""},
    {"v v/ireg", " to become", " devenir", "", "495", "", ""},
    {"v v/ireg", " to begin", " commencer; entreprendre", "", "324", "", ""},
    {"v v/ireg", " to believe", " croire; estimer", "", "290", "", ""},
    {"v v/ireg", " to break", " casser; briser; enfreindre", "", "422", "", ""},
    {"v v/ireg", " to bring", " apporter; amener", "", "149", "", ""},
    {"v v/ireg", " to build", " bâtir; construire; développer", "", "334", "", ""},
    {"v v/ireg", " to buy", " acheter", "", "267", "", ""},
    {"v v/ireg", " to call", " appeler; crier", "", "203", "", ""},
    {"v v/ireg", " to catch", " attraper", "", "469", "", ""},
    {"v v/ireg", " to come", " aller; venir", "", "54", "", ""},
    {"v v/ireg", " to cut", " couper; tailler", "", "304", "", ""},
    {"v v/ireg", " to do", " faire; accomplir", "", "27", "", ""},
    {"v v/ireg", " to draw", " dessiner; tirer; remorquer", "", "370", "", ""},
    {"v v/ireg", " to drive", " conduire", "", "460", "", ""},
    {"v v/ireg", " to eat", " manger", "", "329", "", ""},
    {"v v/ireg", " to fall", " tomber", "", "317", "", ""},
    {"v v/ireg", " to feel", " sentir; croire que", "", "256", "", ""},
    {"v v/ireg", " to find", " trouver; retrouver", "", "117", "", ""},
    {"v v/ireg", " to get", " obtenir; recevoir; avoir", "", "35", "", ""},
    {"v v/ireg", " to give", " donner; offrir", "", "102", "", ""},
    {"v v/ireg", " to go", " aller; s'en aller", "", "34", "", ""},
    {"v v/ireg", " to grow", " croître; grandir; pousser; augmenter", "", "352", "", ""},
    {"v v/ireg", " to have", " avoir; posséder", "", "7", "", ""},
    {"v v/ireg", " to hear", " entendre; écouter; ouïr", "", "208", "", ""},
    {"v v/ireg", " to keep", " garder; retenir; conserver", "", "157", "", ""},
    {"v v/ireg", " to know", " savoir; connaître", "", "63", "", ""},
    {"v v/ireg", " to learn", " apprendre; étudier", "", "371", "", ""},
    {"v v/ireg", " to leave", " quitter; partir", "", "207", "", ""},
    {"v v/ireg", " to lose", " perdre; s'égarer; se perdre", "", "399", "", ""},
    {"v v/ireg", " to make", " faire; créer; fabriquer", "", "61", "", ""},
    {"v v/ireg", " to mean", " signifier; vouloir dire", "", "253", "", ""},
    {"v v/ireg", " to meet", " rencontrer; retrouver; reunir", "", "289", "", ""},
    {"v v/ireg", " to pay", " payer; régler", "", "266", "", ""},
    {"v v/ireg", " to put", " mettre; placer", "", "79", "", ""},
    {"v v/ireg", " to read", " lire", "", "202", "", ""},
    {"v v/ireg", " to run", " courir; se précipiter", "", "146", "", ""},
    {"v v/ireg", " to say", " dire; déclarer", "", "97", "", ""},
    {"v v/ireg", " to see", " voir; regarder; comprendre", "", "47", "", ""},
    {"v v/ireg", " to sell", " vendre; revendre", "", "373", "", ""},
    {"v v/ireg", " to send", " envoyer; expédier", "", "286", "", ""},
    {"v v/ireg", " to set", " placer; poster; mettre", "", "179", "", ""},
    {"v v/ireg", " to show", " montrer; exposer; présenter", "", "151", "", ""},
    {"v v/ireg", " to sit", " s'asseoir; asseoir; siéger; assoir", "", "245", "", ""},
    {"v v/ireg", " to spend", " dépenser; passer [du temps]", "", "404", "", ""},
    {"v v/ireg", " to stand", " se tenir debout; se dresser; supporter", "", "249", "", ""},
    {"v v/ireg", " to take", " prendre; saisir", "", "66", "", ""},
    {"v v/ireg", " to tell", " dire; raconter", "", "92", "", ""},
    {"v v/ireg", " to think", " penser; réfléchir", "", "72", "", ""},
    {"v v/ireg", " to write", " écrire", "", "114", "", ""},
    {"v v/ireg", "bear", "porter; supporter", "", "561", "", ""},
    {"v v/ireg", "beat", "battre; frapper; vaincre", "", "715", "", ""},
    {"v v/ireg", "drink", "boire", "", "626", "", ""},
    {"v v/ireg", "feed", "nourrir; alimenter", "", "692", "", ""},
    {"v v/ireg", "fight", "se bagarrer; battre", "", "534", "", ""},
    {"v v/ireg", "fly", "voler", "", "709", "", ""},
    {"v v/ireg", "hide", "cacher; dissimuler", "", "892", "", ""},
    {"v v/ireg", "hit", "battre; frapper", "", "506", "", ""},
    {"v v/ireg", "lay", "poser; disposer", "", "574", "", ""},
    {"v v/ireg", "mark", "marquer; corriger", "", "828", "", ""},
    {"v v/ireg", "ride", "faire du cheval; monter", "", "845", "", ""},
    {"v v/ireg", "ring", "sonner; faire sonner; appeler; entourer", "", "935", "", ""},
    {"v v/ireg", "shoot", "tirer; fusiller; tuer", "", "708", "", ""},
    {"v v/ireg", "sleep", "dormir; coucher", "", "628", "", ""},
    {"v v/ireg", "stick", "enfoncer; planter; coller; rester", "", "836", "", ""},
    {"v v/ireg", "teach", "enseigner; instruire; éduquer", "", "688", "", ""},
    {"v v/ireg", "to choose", "choisir; décider", "", "524", "", ""},
    {"v v/ireg", "to deal", "distribuer; traiter; faire le trafic de drogues", "", "950", "", ""},
    {"v v/ireg", "to forget", "oublier", "", "535", "", ""},
    {"v v/ireg", "to hang", "pendre; suspendre; accrocher", "", "638", "", ""},
    {"v v/ireg", "to lead", "mener; guider; précéder", "", "515", "", ""},
    {"v v/ireg", "to let", "laisser; laisser faire", "", "616", "", ""},
    {"v v/ireg", "to remain", "rester; demeurer", "", "926", "", ""},
    {"v v/ireg", "to rise", "se lever; s'élever", "", "826", "", ""},
    {"v v/ireg", "to sing", "chanter", "", "783", "", ""},
    {"v v/ireg", "to speak", "parler; dire", "", "545", "", ""},
    {"v v/ireg", "to throw", "jeter; lancer", "", "541", "", ""},
    {"v v/ireg", "to understand", "comprendre; saisir", "", "706", "", ""},
    {"v v/ireg", "to wear", "porter [un vêtement]; mettre", "", "510", "", ""},
    {"v v/ireg", "to win", "gagner", "", "519", "", ""},
    {"v/aux v/ireg", " can", " pouvoir; savoir", "", "42", "", ""},
    {"v/aux", " could", " pouvoir; peut; pouvez [conditionnel]", "", "62", "", ""},
    {"v/aux", " may", " pouvoir", "", "123", "", ""},
    {"v/aux", " might", " pouvoir [pourrait]", "", "186", "", ""},
    {"v/aux", " must", " il faut; devoir", "", "121", "", ""},
    {"v/aux", " should", " devrait; il faut que", "", "104", "", ""},
    {"v/aux", " used to", " être habitué à", "", "497", "", ""},
    {"v/aux", " will", " vouloir; aller faire [futur]", " .", "19", "", ""},
    {"v/aux", " would", " voudrais", "", "33", "", ""},
    {"v", " to add", " ajouter; rajouter; additionner", "", "392", "", ""},
    {"v", " to base", " baser; fonder; se baser", "", "470", "", ""},
    {"v", " to be going to do", " aller faire", "", "168", "", ""},
    {"v", " to carry", " porter; transporter", "", "268", "", ""},
    {"v", " to cause", " causer", "", "427", "", ""},
    {"v", " to change", " changer; modifier", "", "408", "", ""},
    {"v", " to close", " fermer", "", "351", "", ""},
    {"v", " to die", " mourir; décéder", "", "410", "", ""},
    {"v", " to end", " finir; terminer", "", "364", "", ""},
    {"v", " to face", " faire face à; donner sur; rencontrer", "", "417", "", ""},
    {"v", " to follow", " suivre; poursuivre", "", "359", "", ""},
    {"v", " to form", " former; arranger; se faire [une image]", "", "457", "", ""},
    {"v", " to help", " aider; épauler", "", "173", "", ""},
    {"v", " to hope", " espérer; souhaiter", "", "220", "", ""},
    {"v", " to kill", " tuer; assassiner", "", "489", "", ""},
    {"v", " to like", " aimer bien; aimer; apprécier", "", "106", "", ""},
    {"v", " to live", " vivre; habiter", "", "180", "", ""},
    {"v", " to look", " regarder", "", "108", "", ""},
    {"v", " to love", " aimer; adorer", "", "333", "", ""},
    {"v", " to miss", " manquer; rater", "", "424", "", ""},
    {"v", " to move", " bouger; déplacer; déménager", "", "332", "", ""},
    {"v", " to need", " avoir besoin; nécessiter", "", "232", "", ""},
    {"v", " to open", " ouvrir", "", "259", "", ""},
    {"v", " to pass", " passer; franchir", "", "386", "", ""},
    {"v", " to place", " placer; mettre; poser", "", "326", "", ""},
    {"v", " to play", " jouer", "", "118", "", ""},
    {"v", " to present", " présenter; exposer", "", "402", "", ""},
    {"v", " to pull", " tirer; retirer; traîner", "", "459", "", ""},
    {"v", " to remember", " se souvenir; se rappeler", "", "308", "", ""},
    {"v", " to report", " déclarer; rapporter; signaler", "", "413", "", ""},
    {"v", " to seem", " sembler; paraître", "", "448", "", ""},
    {"v", " to start", " démarrer; commencer; entamer", "", "211", "", ""},
    {"v", " to stay", " rester; séjourner", "", "285", "", ""},
    {"v", " to stop", " arrêter; cesser", "", "263", "", ""},
    {"v", " to suppose", " supposer; penser", "", "476", "", ""},
    {"v", " to talk", " parler; dire", "", "254", "", ""},
    {"v", " to try", " essayer; tenter; tâcher; juger [jur]", " tp_gen tp_law", "182", "", ""},
    {"v", " to turn", " tourner; retourner", "", "227", "", ""},
    {"v", " to use", " pratiquer; utiliser", "", "140", "", ""},
    {"v", " to visit", " visiter; aller voir; rendre visite", "", "464", "", ""},
    {"v", " to wait", " patienter; attendre", "", "340", "", ""},
    {"v", " to walk", " marcher; se promener", "", "272", "", ""},
    {"v", " to want", " souhaiter; désirer; vouloir", "", "81", "", ""},
    {"v", " to watch", " regarder; voir; surveiller", "", "311", "", ""},
    {"v", " to wish", " souhaiter; désirer; vouloir", "", "301", "", ""},
    {"v", " to work", " travailler", "", "112", "", ""},
    {"v", "to act", "jouer un rôle; agir; jouer", "", "588", "", ""},
    {"v", "to address", "adresser; nommer", "", "877", "", ""},
    {"v", "to agree", "être d'accord; convenir; accepter", "", "678", "", ""},
    {"v", "to allow", "permettre; laisser", "", "934", "", ""},
    {"v", "to answer", "répondre; riposter", "", "514", "", ""},
    {"v", "to back", "renforcer; appuyer; soutenir", "", "867", "", ""},
    {"v", "to be used to", "être habitué à", "", "835", "", ""},
    {"v", "to check", "contrôler; vérifier; cocher", "", "985", "", ""},
    {"v", "to claim", "réclamer; revendiquer; prétendre", "", "1966", "", ""},
    {"v", "to clear", "nettoyer; acquitter", "", "977", "", ""},
    {"v", "to climb", "escalader; grimper", "", "969", "", ""},
    {"v", "to consider", "considérer; examiner; envisager", "", "936", "", ""},
    {"v", "to continue", "continuer; poursuivre; reprendre", "", "697", "", ""},
    {"v", "to cost", "coûter; estimer", "", "572", "", ""},
    {"v", "to cover", "couvrir; recouvrir", "", "713", "", ""},
    {"v", "to cross", "traverser; se croiser; se rencontrer", "", "786", "", ""},
    {"v", "to cry", "pleurer; crier", "", "862", "", ""},
    {"v", "to decide", "décider", "", "598", "", ""},
    {"v", "to develop", "développer; évoluer", "", "789", "", ""},
    {"v", "to dress", "habiller; s'habiller; se vêtir", "", "816", "", ""},
    {"v", "to drop", "laisser tomber; lâcher", "", "582", "", ""},
    {"v", "to enjoy", "s'amuser; jouir de; jouir", "", "772", "", ""},
    {"v", "to ensure", "assurer; garantir", "", "568", "", ""},
    {"v", "to enter", "entrer; inscrire; pénétrer", "", "767", "", ""},
    {"v", "to fill", "emplir; remplir", "", "779", "", ""},
    {"v", "to finish", "terminer; achever; finir", "", "685", "", ""},
    {"v", "to fit", "aller à; aller dans; être en harmonie; aller avec", "", "939", "", ""},
    {"v", "to hand", "donner; passer", "", "872", "", ""},
    {"v", "to happen", "arriver; se produire; survenir", "", "554", "", ""},
    {"v", "to head", "présider; venir en tête", "", "705", "", ""},
    {"v", "to house", "loger; héberger; abriter", "", "814", "", ""},
    {"v", "to join", "devenir membre; joindre; relier", "", "968", "", ""},
    {"v", "to jump", "sauter; sursauter", "", "929", "", ""},
    {"v", "to last", "durer; persister", "", "791", "", ""},
    {"v", "to laugh", "rire; blaguer", "", "615", "", ""},
    {"v", "to listen", "écouter; ausculter", "", "645", "", ""},
    {"v", "to marry", "épouser; marier", "", "819", "", ""},
    {"v", "to mind", "faire attention à; être gêné de", "", "721", "", ""},
    {"v", "to name", "appeler; citer; nommer", "", "589", "", ""},
    {"v", "to note", "noter; remarquer", "", "730", "", ""},
    {"v", "to order", "ordonner; commander", "", "956", "", ""},
    {"v", "to own", "avoir; posseder", "", "753", "", ""},
    {"v", "to pick", "choisir; cueillir", "", "904", "", ""},
    {"v", "to plan", "planifier; projeter", "", "804", "", ""},
    {"v", "to practise", "s'entraîner; exercer; pratiquer", "", "551", "", ""},
    {"v", "to prepare", "préparer; faire; confectionner", "", "938", "", ""},
    {"v", "to produce", "produire", "", "853", "", ""},
    {"v", "to push", "pousser; presser; appuyer sur", "", "593", "", ""},
    {"v", "to raise", "lever; soulever; hausser", "", "611", "", ""},
    {"v", "to reach", "atteindre; arriver à; accéder", "", "501", "", ""},
    {"v", "to receive", "recevoir; acceuillir", "", "817", "", ""},
    {"v", "to recognise", "reconnaître; identifier", "", "907", "", ""},
    {"v", "to rest", "reposer; rester", "", "954", "", ""},
    {"v", "to return", "revenir; retourner; rendre", "", "737", "", ""},
    {"v", "to rule", "gouverner; décider; statuer; dominer", "tp_law", "881", "", ""},
    {"v", "to save", "sauvegarder; sauver", "", "673", "", ""},
    {"v", "to sign", "signer; indiquer; faire un signe", "", "680", "", ""},
    {"v", "to smile", "sourire", "", "609", "", ""},
    {"v", "to sound", "retentir; entendre; sonner", "", "584", "", ""},
    {"v", "to study", "étudier", "", "691", "", ""},
    {"v", "to test", "expérimenter; essayer", "", "805", "", ""},
    {"v", "to thank", "remercier; dire merci", "", "513", "", ""},
    {"v", "to touch", "toucher; effleurer", "", "911", "", ""},
    {"v", "to train", "former; entraîner; éduquer", "", "723", "", ""},
    {"v", "to travel", "voyager; faire un voyage", "", "868", "", ""},
    {"v", "to voice", "exprimer; sonoriser", "", "965", "", ""},
    {"v", "to wonder", "s'étonner; penser", "", "720", "", ""}
]

pprint.pprint(myvar)
print(type(myvar))  # list
print(myvar[5])
